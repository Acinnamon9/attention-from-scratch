# %% [markdown]
# # Title: Attention Core
#
# This file intentionally avoids frameworks and autograd. The functions
# include shape checks and optional verbose prints to help you inspect the
# intermediate matrices during learning experiments.

# %% [markdown]
# Goal: To understand attention as a routing mechanism independent of the transformer architecture.

# %% [markdown]
# Setup:

# %% [markdown]
# Experiment:

# %% [markdown]
# Observation:

# %% [markdown]
# Interpretation:
